# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.load('exact_data1_t_time12.npy')
x = np.load('exact_data1_x_time12.npy')
v = np.load('exact_data1_v_time12.npy')

# %%
print(t.shape, x.shape, v.shape)
# Out:
# (1201,) (600,) (1201, 600)

# %%
# Plot the analytical solution.
plt.figure(figsize=(6.0, 4.0))
plt.xlabel('x')
plt.ylabel('v')
plt.grid()
#plt.plot(x, u_sol[0,:], label='Initial',
 #           color='C0', linestyle='-', linewidth=2)
plt.plot(x, v[0], label='v(x,0)',
            color='C0', linestyle='-', linewidth=2)
#plt.plot(x, u_sol[-1,:], label='Analytical',
#            color='C1', linestyle='--', linewidth=2)
plt.plot(x, v[-1], label='u(x,t)',
            color='C1', linestyle='--', linewidth=2)
plt.title('$t = %.2f$' % (t[-1]), fontsize = 14)

plt.show()
